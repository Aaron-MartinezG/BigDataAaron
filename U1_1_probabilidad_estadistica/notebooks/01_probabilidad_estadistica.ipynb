# %% [markdown]
# # Práctica 1.1 — Probabilidad y Estadística
#
# ## Aarón Martínez Garcidueñas - 511
#
# ### Análisis de la evolución poblacional mundial
#
# ### Objetivo
#
# Utilizar un conjunto de datos real para comprobar el funcionamiento del entorno de análisis de datos y aplicar medidas estadísticas descriptivas básicas utilizando Pandas y NumPy.

# %% [markdown]
# ## Actividad 1 — Identificación de la fuente

# %% [markdown]
# ### Cita de la fuente:
#
# ["Annual change in population"](https://ourworldindata.org/grapher/annual-population-growth?v=1&csvType=full&useColumnShortNames=false) on the Our World in Data website.
#
# United Nations, World Population Prospects (2024)
#
# UN, World Population Prospects (2024) – processed by Our World in Data. “Annual change in population – UN WPP” [dataset]. United Nations, “World Population Prospects”; United Nations, “World Population Prospects - Interim Update” [original data].

# %% [markdown]
# 1.	**¿Quién produjo originalmente los datos?**
# Las naciones unidas en World Population Prospects (2024)
# 2.	**¿Qué organización los procesa para su utilización en Our World in Data?**
# Los procesa la organización Our World in Data para su sitio
# 3.	**¿Qué representa la variable que analizarás?**
# El cambio de la población mundial y sus proyecciones

# %% [markdown]
# ## Actividad 2 - Carga y exploración de datos

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/annual-population-growth/annual-population-growth.csv")

# %%
df.head()
# Out:
#         Entity Code  Year  Annual change in population  \
# 0  Afghanistan  AFG  1951                     103163.0
# 1  Afghanistan  AFG  1952                     108441.0
# 2  Afghanistan  AFG  1953                     108919.0
# 3  Afghanistan  AFG  1954                     111251.0
# 4  Afghanistan  AFG  1955                     119027.0
#
#    Annual population change (Projected)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN

# %%
df.shape
# Out:
# (38400, 5)

# %%
df.columns.tolist()
# Out:
# ['Entity',
#  'Code',
#  'Year',
#  'Annual change in population',
#  'Annual population change (Projected)']

# %%
df.dtypes
# Out:
# Entity                                      str
# Code                                        str
# Year                                      int64
# Annual change in population             float64
# Annual population change (Projected)    float64
# dtype: object

# %%
df.describe()
# Out:
#                Year  Annual change in population  \
# count  38400.000000                 1.868800e+04
# mean    2025.500000                 2.063019e+06
# std       43.300872                 9.440859e+06
# min     1951.000000                -3.315935e+06
# 25%     1988.000000                 1.781000e+03
# 50%     2025.500000                 4.689800e+04
# 75%     2063.000000                 3.021128e+05
# max     2100.000000                 9.337137e+07
#
#        Annual population change (Projected)
# count                          1.971200e+04
# mean                           8.375481e+05
# std                            5.816745e+06
# min                           -2.291035e+07
# 25%                           -9.742750e+03
# 50%                            9.350000e+01
# 75%                            1.411160e+05
# max                            7.206736e+07

# %%
df.isnull().sum()
# Out:
# Entity                                      0
# Code                                     1200
# Year                                        0
# Annual change in population             19712
# Annual population change (Projected)    18688
# dtype: int64

# %%
print(df["Entity"].nunique())
# Out:
# 256

# %% [markdown]
# 1.	**¿Cuántas filas y columnas tiene el dataset?**
# 38,400 filas y 5 columnas
# 2.	**¿Qué tipo de datos contiene la variable Year?**
# Contiene datos del tipo entero (int)
# 3.	**¿Existen valores faltantes?**
# Si, de código y de cambio anual en población normal y proyectado.
# 4.	**¿Cuántas entidades diferentes contiene el dataset?**
# 256

# %% [markdown]
# ## Actividad 3 - Estadística descriptiva

# %%
df_extration_filas = df[df["Year"]==2020]

# %%
print(f"La media es {df_extration_filas["Annual change in population"].mean()}")
# Out:
# La media es 2124908.84765625

# %%
print(f"La mediana es {df_extration_filas["Annual change in population"].median()}")
# Out:
# La mediana es 34293.5

# %%
print(f"La varianza es {df_extration_filas["Annual change in population"].var()}")
# Out:
# La varianza es 90687335031103.64

# %%
print(f"La desviación estándar es {df_extration_filas["Annual change in population"].std()}")
# Out:
# La desviación estándar es 9522989.815761836

# %%
print(f"El mínimo es {df_extration_filas["Annual change in population"].min()}")
# Out:
# El mínimo es -494016.0

# %%
print(f"El máximo es {df_extration_filas["Annual change in population"].max()}")
# Out:
# El máximo es 75707590.0

# %%
df_extration_filas[df_extration_filas["Annual change in population"] == -494016.0]
# Out:
#           Entity Code  Year  Annual change in population  \
# 37269  Venezuela  VEN  2020                    -494016.0
#
#        Annual population change (Projected)
# 37269                                   NaN

# %% [markdown]
# 1.	**¿Cuál es el valor de la media?**
# La media es 2124908.84765625
# 2.	**¿Cuál es el valor de la mediana?**
# La mediana es 34293.5
# 3.	**¿Cuál es el valor de la desviación estándar?**
# La desviación estándar es 9522989.815761836
# 4.	**¿Qué entidad presenta el valor mínimo y cuál el máximo?**
# Venezuela presenta el mínimo y el máximo es 75707590.0

# %% [markdown]
# ## Actividad 4 - Comprobación del entorno

# %%
import sys

print("Python:", sys.version)
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
# Out:
# Python: 3.13.3 (tags/v3.13.3:6280bb5, Apr  8 2025, 14:47:33) [MSC v.1943 64 bit (AMD64)]
# Pandas: 3.0.5
# NumPy: 2.5.2

# %%
df[df['Entity'] == 'Mexico']
# Out:
#        Entity Code  Year  Annual change in population  \
# 22200  Mexico  MEX  1951                     732546.0
# 22201  Mexico  MEX  1952                     769686.0
# 22202  Mexico  MEX  1953                     809069.0
# 22203  Mexico  MEX  1954                     853770.0
# 22204  Mexico  MEX  1955                     897588.0
# ...       ...  ...   ...                          ...
# 22345  Mexico  MEX  2096                          NaN
# 22346  Mexico  MEX  2097                          NaN
# 22347  Mexico  MEX  2098                          NaN
# 22348  Mexico  MEX  2099                          NaN
# 22349  Mexico  MEX  2100                          NaN
#
#        Annual population change (Projected)
# 22200                                   NaN
# 22201                                   NaN
# 22202                                   NaN
# 22203                                   NaN
# 22204                                   NaN
# ...                                     ...
# ...

# %%
df_extration_filas = df[df["Year"]==2020]
df_extration_filas
# Out:
#                Entity      Code  Year  Annual change in population  \
# 69        Afghanistan       AFG  2020                    1212852.0
# 219       Africa (UN)    UN_AFR  2020                   32815675.0
# 369           Albania       ALB  2020                     -13061.0
# 519           Algeria       DZA  2020                     747543.0
# 669    American Samoa       ASM  2020                       -451.0
# ...               ...       ...   ...                          ...
# 37719  Western Sahara       ESH  2020                      10924.0
# 37869           World  OWID_WRL  2020                   75707590.0
# 38019           Yemen       YEM  2020                    1023451.0
# 38169          Zambia       ZMB  2020                     545555.0
# 38319        Zimbabwe       ZWE  2020                     255510.0
#
#        Annual population change (Projected)
# 69                                      NaN
# 219                                     NaN
# ...

# %%
df_2006_2020_mex = df[(df["Entity"] == "Mexico") & (df["Year"]>=2006) & (df["Year"]<=2020)]
df_extraction_range = df_2006_2020_mex[["Entity", "Year", "Annual change in population"]]
df_extraction_range
# Out:
#        Entity  Year  Annual change in population
# 22255  Mexico  2006                    1442162.0
# 22256  Mexico  2007                    1520690.0
# 22257  Mexico  2008                    1599930.0
# 22258  Mexico  2009                    1625434.0
# 22259  Mexico  2010                    1624178.0
# 22260  Mexico  2011                    1619605.0
# 22261  Mexico  2012                    1574705.0
# 22262  Mexico  2013                    1525364.0
# 22263  Mexico  2014                    1440693.0
# 22264  Mexico  2015                    1288045.0
# 22265  Mexico  2016                    1179034.0
# 22266  Mexico  2017                    1148708.0
# 22267  Mexico  2018                    1173661.0
# 22268  Mexico  2019                    1189265.0
# 22269  Mexico  2020                    1036075.0

# %%
df_new = df[["Entity"]]
df_new
# Out:
#             Entity
# 0      Afghanistan
# 1      Afghanistan
# 2      Afghanistan
# 3      Afghanistan
# 4      Afghanistan
# ...            ...
# 38395     Zimbabwe
# 38396     Zimbabwe
# 38397     Zimbabwe
# 38398     Zimbabwe
# 38399     Zimbabwe
#
# [38400 rows x 1 columns]

# %%
df.iloc[30:35]
# Out:
#          Entity Code  Year  Annual change in population  \
# 30  Afghanistan  AFG  1981                   -1231727.0
# 31  Afghanistan  AFG  1982                    -946206.0
# 32  Afghanistan  AFG  1983                     -73395.0
# 33  Afghanistan  AFG  1984                     272237.0
# 34  Afghanistan  AFG  1985                     236633.0
#
#     Annual population change (Projected)
# 30                                   NaN
# 31                                   NaN
# 32                                   NaN
# 33                                   NaN
# 34                                   NaN

# %%
df.loc[10000]
# Out:
# Entity                                  Equatorial Guinea
# Code                                                  GNQ
# Year                                                 2051
# Annual change in population                           NaN
# Annual population change (Projected)              46407.0
# Name: 10000, dtype: object

# %%
df.loc[:,["Entity","Year","Annual change in population"]]
# Out:
#             Entity  Year  Annual change in population
# 0      Afghanistan  1951                     103163.0
# 1      Afghanistan  1952                     108441.0
# 2      Afghanistan  1953                     108919.0
# 3      Afghanistan  1954                     111251.0
# 4      Afghanistan  1955                     119027.0
# ...            ...   ...                          ...
# 38395     Zimbabwe  2096                          NaN
# 38396     Zimbabwe  2097                          NaN
# 38397     Zimbabwe  2098                          NaN
# 38398     Zimbabwe  2099                          NaN
# 38399     Zimbabwe  2100                          NaN
#
# [38400 rows x 3 columns]

# %%
df.loc[(df["Entity"]=="Mexico") & (df["Year"]==2020)]
# Out:
#        Entity Code  Year  Annual change in population  \
# 22269  Mexico  MEX  2020                    1036075.0
#
#        Annual population change (Projected)
# 22269                                   NaN

# %%
df.loc[0:5]
# Out:
#         Entity Code  Year  Annual change in population  \
# 0  Afghanistan  AFG  1951                     103163.0
# 1  Afghanistan  AFG  1952                     108441.0
# 2  Afghanistan  AFG  1953                     108919.0
# 3  Afghanistan  AFG  1954                     111251.0
# 4  Afghanistan  AFG  1955                     119027.0
# 5  Afghanistan  AFG  1956                     127322.0
#
#    Annual population change (Projected)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN

# %%
df.iloc[:, 0:3]
# Out:
#             Entity Code  Year
# 0      Afghanistan  AFG  1951
# 1      Afghanistan  AFG  1952
# 2      Afghanistan  AFG  1953
# 3      Afghanistan  AFG  1954
# 4      Afghanistan  AFG  1955
# ...            ...  ...   ...
# 38395     Zimbabwe  ZWE  2096
# 38396     Zimbabwe  ZWE  2097
# 38397     Zimbabwe  ZWE  2098
# 38398     Zimbabwe  ZWE  2099
# 38399     Zimbabwe  ZWE  2100
#
# [38400 rows x 3 columns]

# %%
ds_apellido = df.loc[(df["Entity"]=="Morocco") & (df["Year"]>=2006) & (df["Year"]<=2023)]
ds_apellido
# Out:
#         Entity Code  Year  Annual change in population  \
# 23455  Morocco  MAR  2006                     413034.0
# 23456  Morocco  MAR  2007                     415289.0
# 23457  Morocco  MAR  2008                     420301.0
# 23458  Morocco  MAR  2009                     424010.0
# 23459  Morocco  MAR  2010                     436230.0
# 23460  Morocco  MAR  2011                     445576.0
# 23461  Morocco  MAR  2012                     442661.0
# 23462  Morocco  MAR  2013                     432327.0
# 23463  Morocco  MAR  2014                     417211.0
# 23464  Morocco  MAR  2015                     402806.0
# 23465  Morocco  MAR  2016                     415869.0
# 23466  Morocco  MAR  2017                     422936.0
# 23467  Morocco  MAR  2018                     393365.0
# 23468  Morocco  MAR  2019                     371147.0
# 23469  Morocco  MAR  2020                     373301.0
# 23470  Morocco  MAR  2021                     370235.0
# ...

# %%
print(f"Media:  {ds_apellido["Annual change in population"].mean()}")
print(f"Mediana:  {ds_apellido["Annual change in population"].median()}")
print(f"Desviación estándar:  {ds_apellido["Annual change in population"].std()}")
print(f"Mínimo:  {ds_apellido["Annual change in population"].min()}")
print(f"Máximo:  {ds_apellido["Annual change in population"].max()}")
# Out:
# Media:  408576.1666666667
# Mediana:  415579.0
# Desviación estándar:  25203.01788943725
# Mínimo:  370235.0
# Máximo:  445576.0

# %% [markdown]
# Bye
